# %%
import pandas as pd

# %%
hjDF=pd.read_csv('./서울특별시 행정동별 친환경자동차 현황-제원번호 포함 자료(2022.2.28).CSV', encoding='cp949')

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
#         현소유자의출생년도             제원관리번호
# 0          1977.0  01020007000041319
# 1          1959.0  A0810010800451317
# 2          1942.0  01020006500091320
# 3          1966.0  01020006800021320
# 4          1970.0  01020007000041319
# ...           ...                ...
# 189581     1982.0  01020006500001317
# 189582     1979.0  A0810008700781314
# 189583     1979.0  A0110006100091217
# 189584     1967.0  A0810006219283120
# 189585        NaN  A0110004700101211
#
# [189586 rows x 7 columns]

# %%
# 기준년월 unique :  202202밖에..
hjDF['기준년월']
# Out:
# <bound method Series.unique of 0         202202
# 1         202202
# 2         202202
# 3         202202
# 4         202202
#            ...
# 189581    202202
# 189582    202202
# 189583    202202
# 189584    202202
# 189585    202202
# Name: 기준년월, Length: 189586, dtype: int64>

# %%
hjDF['최초등록일'].
# Out:
# dtype('int64')

# %%
hjDF['최초등록일_날짜'] = pd.to_datetime(hjDF['최초등록일'])

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
#         현소유자의출생년도             제원관리번호                      최초등록일_날짜
# 0          1977.0  01020007000041319 1970-01-01 00:00:00.020200910
# 1          1959.0  A0810010800451317 1970-01-01 00:00:00.020170710
# 2          1942.0  01020006500091320 1970-01-01 00:00:00.020210309
# 3          1966.0  01020006800021320 1970-01-01 00:00:00.020210528
# 4          1970.0  01020007000041319 1970-01-01 00:00:00.020200630
# ...           ...                ...                           ...
# 189581     1982.0  01020006500001317 1970-01-01 00:00:00.020180824
# 189582     1979.0  A0810008700781314 1970-01-01 00:00:00.020150212
# 189583     1979.0  A0110006100091217 1970-01-01 00:00:00.020180109
# 189584     1967.0  A0810006219283120 1970-01-01 00:00:00.020210315
# 189585        NaN  A0110004700101211 1970-01-01 00:00:00.020120105
#
# [189586 rows x 8 columns]

# %%
hjDF=hjDF.drop(['최초등록일_날짜'], axis=1)

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
#         현소유자의출생년도             제원관리번호
# 0          1977.0  01020007000041319
# 1          1959.0  A0810010800451317
# 2          1942.0  01020006500091320
# 3          1966.0  01020006800021320
# 4          1970.0  01020007000041319
# ...           ...                ...
# 189581     1982.0  01020006500001317
# 189582     1979.0  A0810008700781314
# 189583     1979.0  A0110006100091217
# 189584     1967.0  A0810006219283120
# 189585        NaN  A0110004700101211
#
# [189586 rows x 7 columns]

# %%
hjDF['최초등록일'].astype('str')
# Out:
# 0         20200910
# 1         20170710
# 2         20210309
# 3         20210528
# 4         20200630
#             ...
# 189581    20180824
# 189582    20150212
# 189583    20180109
# 189584    20210315
# 189585    20120105
# Name: 최초등록일, Length: 189586, dtype: object

# %%
hjDF['최초등록일_날짜'] = pd.to_datetime(hjDF['최초등록일'])

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
#         현소유자의출생년도             제원관리번호                      최초등록일_날짜
# 0          1977.0  01020007000041319 1970-01-01 00:00:00.020200910
# 1          1959.0  A0810010800451317 1970-01-01 00:00:00.020170710
# 2          1942.0  01020006500091320 1970-01-01 00:00:00.020210309
# 3          1966.0  01020006800021320 1970-01-01 00:00:00.020210528
# 4          1970.0  01020007000041319 1970-01-01 00:00:00.020200630
# ...           ...                ...                           ...
# 189581     1982.0  01020006500001317 1970-01-01 00:00:00.020180824
# 189582     1979.0  A0810008700781314 1970-01-01 00:00:00.020150212
# 189583     1979.0  A0110006100091217 1970-01-01 00:00:00.020180109
# 189584     1967.0  A0810006219283120 1970-01-01 00:00:00.020210315
# 189585        NaN  A0110004700101211 1970-01-01 00:00:00.020120105
#
# [189586 rows x 8 columns]

# %%
hjDF=hjDF.drop(['최초등록일_날짜'], axis=1)

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
#         현소유자의출생년도             제원관리번호
# 0          1977.0  01020007000041319
# 1          1959.0  A0810010800451317
# 2          1942.0  01020006500091320
# 3          1966.0  01020006800021320
# 4          1970.0  01020007000041319
# ...           ...                ...
# 189581     1982.0  01020006500001317
# 189582     1979.0  A0810008700781314
# 189583     1979.0  A0110006100091217
# 189584     1967.0  A0810006219283120
# 189585        NaN  A0110004700101211
#
# [189586 rows x 7 columns]

# %%
hjDF['최초등록일']=hjDF['최초등록일'].astype('str')

# %%
hjDF['최초등록일'].dtype
# Out:
# dtype('O')

# %%
hjDF['최초등록일_년도']=hjDF['최초등록일'].str[:4]

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
#         현소유자의출생년도             제원관리번호 최초등록일_년도
# 0          1977.0  01020007000041319     2020
# 1          1959.0  A0810010800451317     2017
# 2          1942.0  01020006500091320     2021
# 3          1966.0  01020006800021320     2021
# 4          1970.0  01020007000041319     2020
# ...           ...                ...      ...
# 189581     1982.0  01020006500001317     2018
# 189582     1979.0  A0810008700781314     2015
# 189583     1979.0  A0110006100091217     2018
# 189584     1967.0  A0810006219283120     2021
# 189585        NaN  A0110004700101211     2012
#
# [189586 rows x 8 columns]

# %%
vcDF=pd.DataFrame(hjDF['최초등록일_년도'].value_counts())

# %%
vcDF.to_csv('년도별_valuecounts.csv')

# %%
vcDF
# Out:
#       최초등록일_년도
# 2021     50847
# 2020     35929
# 2019     23576
# 2018     20916
# 2017     16469
# 2016     10690
# 2015      6597
# 2022      5882
# 2014      5306
# 2012      4913
# 2013      4015
# 2011      2348
# 2010       960
# 2009       779
# 2008       207
# 2007       122
# 2006        24
# 2005         6

# %%
hjDF
# Out:
#           기준년월 사용본거지시읍면동_행정동기준                    차명             연료     최초등록일  \
# 0       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200910
# 1       202202  서울특별시 강남구 개포1동             그랜저 하이브리드  하이브리드(휘발유+전기)  20170710
# 2       202202  서울특별시 강남구 개포1동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20210309
# 3       202202  서울특별시 강남구 개포1동            렉서스 ES300h  하이브리드(휘발유+전기)  20210528
# 4       202202  서울특별시 강남구 개포1동   토요타 RAV4 Hybrid AWD  하이브리드(휘발유+전기)  20200630
# ...        ...             ...                   ...            ...       ...
# 189581  202202  서울특별시 중랑구 중화2동      토요타 Camry Hybrid  하이브리드(휘발유+전기)  20180824
# 189582  202202  서울특별시 중랑구 중화2동   그랜저(GRANDEUR) 하이브리드  하이브리드(휘발유+전기)  20150212
# 189583  202202  서울특별시 중랑구 중화2동              니로 하이브리드  하이브리드(휘발유+전기)  20180109
# 189584  202202  서울특별시 중랑구 중화2동  포터Ⅱ 일렉트릭 (PORTERⅡ EL             전기  20210315
# 189585  202202             NaN              K5 하이브리드  하이브리드(휘발유+전기)  20120105
#
#         현소유자의출생년도             제원관리번호 최초등록일_년도
# 0          1977.0  01020007000041319     2020
# 1          1959.0  A0810010800451317     2017
# 2          1942.0  01020006500091320     2021
# 3          1966.0  01020006800021320     2021
# 4          1970.0  01020007000041319     2020
# ...           ...                ...      ...
# 189581     1982.0  01020006500001317     2018
# 189582     1979.0  A0810008700781314     2015
# 189583     1979.0  A0110006100091217     2018
# 189584     1967.0  A0810006219283120     2021
# 189585        NaN  A0110004700101211     2012
#
# [189586 rows x 8 columns]

# %%
hjDF.isna().sum()
# Out:
# 기준년월                   0
# 사용본거지시읍면동_행정동기준       11
# 차명                     0
# 연료                     0
# 최초등록일                  0
# 현소유자의출생년도          44764
# 제원관리번호                 0
# 최초등록일_년도               0
# dtype: int64

# %%
import numpy as np

# %%
hjDF['사용본거지시읍면동_행정동기준'].unique()
# Out:
# array(['서울특별시 강남구 개포1동', '서울특별시 강남구 개포2동', '서울특별시 강남구 개포4동',
#        '서울특별시 강남구 논현1동', '서울특별시 강남구 논현2동', '서울특별시 강남구 대치1동',
#        '서울특별시 동작구 상도1동', '서울특별시 동작구 상도2동', '서울특별시 동작구 상도3동',
#        '서울특별시 동작구 상도4동', '서울특별시 동작구 신대방1동', '서울특별시 동작구 신대방2동',
#        '서울특별시 동작구 흑석동', '서울특별시 마포구 공덕동', '서울특별시 강남구 대치2동',
#        '서울특별시 마포구 대흥동', '서울특별시 마포구 도화동', '서울특별시 마포구 망원1동',
#        '서울특별시 마포구 망원2동', '서울특별시 마포구 상암동', '서울특별시 마포구 서강동',
#        '서울특별시 강남구 대치4동', '서울특별시 마포구 서교동', '서울특별시 마포구 성산1동',
#        '서울특별시 마포구 성산2동', '서울특별시 마포구 신수동', '서울특별시 마포구 아현동',
#        '서울특별시 강남구 도곡1동', '서울특별시 마포구 연남동', '서울특별시 마포구 염리동',
#        '서울특별시 마포구 용강동', '서울특별시 강남구 도곡2동', '서울특별시 마포구 합정동',
#        '서울특별시 서대문구 남가좌1동', '서울특별시 강남구 삼성1동', '서울특별시 서대문구 남가좌2동',
#        '서울특별시 강남구 삼성2동', '서울특별시 서대문구 북가좌1동', '서울특별시 서대문구 북가좌2동',
#        '서울특별시 강남구 세곡동', '서울특별시 서대문구 북아현동', '서울특별시 서대문구 신촌동',
#        '서울특별시 서대문구 연희동', '서울특별시 서대문구 천연동', '서울특별시 강남구 수서동',
#        '서울특별시 강남구 신사동', '서울특별시 서대문구 충현동', '서울특별시 서대문구 홍은1동',
#        '서울특별시 강남구 압구정동', '서울특별시 서대문구 홍은2동', '서울특별시 서대문구 홍제1동',
#        '서울특별시 강남구 역삼1동', '서울특별시 서대문구 홍제2동', '서울특별시 서대문구 홍제3동',
#        '서울특별시 서초구 내곡동', '서울특별시 서초구 반포1동', '서울특별시 서초구 반포2동',
#        '서울특별시 서초구 반포3동', '서울특별시 서초구 반포4동', '서울특별시 서초구 반포본동',
#        '서울특별시 서초구 방배1동', '서울특별시 강남구 역삼2동', '서울특별시 서초구 방배2동',
#        '서울특별시 서초구 방배3동', '서울특별시 강남구 일원1동', '서울특별시 서초구 방배4동',
#        '서울특별시 강남구 일원2동', '서울특별시 강남구 일원본동', '서울특별시 서초구 방배본동',
#        '서울특별시 서초구 서초1동', '서울특별시 강남구 청담동', '서울특별시 강동구 강일동',
#        '서울특별시 강동구 고덕1동', '서울특별시 서초구 서초2동', '서울특별시 강동구 고덕2동',
#        '서울특별시 서초구 서초3동', '서울특별시 서초구 서초4동', '서울특별시 서초구 양재1동',
# 0        급속  영등포전력지사  서울특별시 영등포구 경인로 878   50.0   0.05   0.0   0.0
# 1        급속  영등포전력지사  서울특별시 영등포구 경인로 878   50.0  13.10   0.0  29.0
# 2        급속  영등포전력지사  서울특별시 영등포구 경인로 878   50.0  47.56   1.0  33.0
# 3        급속  영등포전력지사  서울특별시 영등포구 경인로 878   50.0  24.77   0.0  38.0
# 4        급속  영등포전력지사  서울특별시 영등포구 경인로 878   50.0  19.21   0.0  29.0
# ...     ...      ...                 ...    ...    ...   ...   ...
# 638697   급속  서울전력관리처    서울특별시 중구 퇴계로 140   50.0  41.67   1.0  21.0
# 638698   급속  서울전력관리처    서울특별시 중구 퇴계로 140   50.0  29.07   0.0  44.0
# 638699   급속  서울전력관리처    서울특별시 중구 퇴계로 140   50.0  55.65   1.0  21.0
# 638700   급속  서울전력관리처    서울특별시 중구 퇴계로 140   50.0  21.48   1.0   3.0
# 638701   급속  서울전력관리처    서울특별시 중구 퇴계로 140   50.0  13.56   0.0  24.0
#
#                   충전시작시각            충전종료시각
# 0        2021-01-01 2:06   2021-01-01 2:06
# 1       2021-01-02 14:58  2021-01-02 15:28
# 2       2021-01-02 20:57  2021-01-02 22:31
# 3       2021-01-04 12:12  2021-01-04 12:51
# 4       2021-01-04 22:51  2021-01-04 23:21
# ...                  ...               ...
# 638697   2022-03-31 9:44  2022-03-31 11:05
# 638698  2022-03-31 12:17  2022-03-31 13:02
# 638699  2022-03-31 16:57  2022-03-31 18:19
# 638700  2022-03-31 13:06  2022-03-31 14:09
# 638701   2022-03-31 7:27   2022-03-31 7:51
#
# [638702 rows x 9 columns]

# %%
chargingDF.isna().sum()
# Out:
# 충전구분           0
# 충전소명           0
# 주소          1488
# 충전기용량     104677
# 충전량       103510
# 충전시간      103510
# 충전분       103510
# 충전시작시각    103510
# 충전종료시각    103510
# dtype: int64

# %%
chargingDF[['충전구분', '충전소명', '주소']]
# Out:
#        충전구분     충전소명                  주소
# 0        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 1        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 2        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 3        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 4        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# ...     ...      ...                 ...
# 638697   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638698   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638699   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638700   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638701   급속  서울전력관리처    서울특별시 중구 퇴계로 140
#
# [638702 rows x 3 columns]

# %%
chargingDF[['충전구분', '충전소명', '주소']].isna().sum()
# Out:
# 충전구분       0
# 충전소명       0
# 주소      1488
# dtype: int64

# %%
chargingDF_2=chargingDF[['충전구분', '충전소명', '주소']]

# %%
chargingDF_2
# Out:
#        충전구분     충전소명                  주소
# 0        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 1        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 2        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 3        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# 4        급속  영등포전력지사  서울특별시 영등포구 경인로 878
# ...     ...      ...                 ...
# 638697   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638698   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638699   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638700   급속  서울전력관리처    서울특별시 중구 퇴계로 140
# 638701   급속  서울전력관리처    서울특별시 중구 퇴계로 140
#
# [638702 rows x 3 columns]

# %%
chargingDF_2 =chargingDF_2[chargingDF_2.duplicated() ==False].reset_index(drop = True)

# %%
chargingDF_2[chargingDF_2.isna().sum(1)>0]
# Out:
#     충전구분        충전소명   주소
# 152   급속  여의도KBS (본관  NaN
# 477   완속       면목두산2  NaN
# 485   완속       면목두산4  NaN
# 488   급속       면목두산4  NaN
# 516   급속       면목두산2  NaN

# %%
#chargingDF_2[chargingDF_2.isna().sum(1)>0]['주소'][152].fillna('서울 영등포구 여의공원로 13')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [134], in <cell line: 1>()
# ----> 1 chargingDF_2[chargingDF_2.isna().sum(1)>0]['주소'][152].fillna('서울 영등포구 여의공원로 13')
#
# AttributeError: 'float' object has no attribute 'fillna'

# %%
# 조건식으로 찾아서 대체?
chargingDF_2['주소'][152]
# Out:
# 0            서울특별시 영등포구 경인로 878
# 1            서울특별시 영등포구 경인로 878
# 2                경기도 하남시 감북로 80
# 3       서울특별시 강동구 구천면로 395(명일동)
# 4      서울특별시 송파구 마천동 성내천로37길 37
#                  ...
# 870       서울특별시 강북구 월계로 173 (번동
# 871     서울특별시 성북구 동소문로 315 (길음동
# 872      서울특별시 강북구 삼각산로 85 (수유동
# 873            서울특별시 중구 퇴계로 140
# 874            서울특별시 중구 퇴계로 140
# Name: 주소, Length: 875, dtype: object

# %%
chargingDF_2[chargingDF_2.isna().sum(1)>0]
# Out:
#     충전구분        충전소명   주소
# 152   급속  여의도KBS (본관  NaN
# 477   완속       면목두산2  NaN
# 485   완속       면목두산4  NaN
# 488   급속       면목두산4  NaN
# 516   급속       면목두산2  NaN

# %%
chargingDF_2
# Out:
#     충전구분           충전소명                        주소
# 0     급속        영등포전력지사        서울특별시 영등포구 경인로 878
# 1     완속        영등포전력지사        서울특별시 영등포구 경인로 878
# 2     완속       동서울 전력지사            경기도 하남시 감북로 80
# 3     급속      명일동 공영주차장   서울특별시 강동구 구천면로 395(명일동)
# 4     완속  송파파크데일1단지 아파트  서울특별시 송파구 마천동 성내천로37길 37
# ..   ...            ...                       ...
# 870   급속         북서울꿈의숲     서울특별시 강북구 월계로 173 (번동
# 871   급속      현대백화점 미아점   서울특별시 성북구 동소문로 315 (길음동
# 872   급속       강북문화예술회관    서울특별시 강북구 삼각산로 85 (수유동
# 873   급속        서울전력관리처          서울특별시 중구 퇴계로 140
# 874   완속        서울전력관리처          서울특별시 중구 퇴계로 140
#
# [875 rows x 3 columns]

# %%
[add for add in chargingDF_2['주소'].str.split('(')]
# Out:
# [['서울특별시 영등포구 경인로 878'],
#  ['서울특별시 영등포구 경인로 878'],
#  ['경기도 하남시 감북로 80'],
#  ['서울특별시 강동구 구천면로 395', '명일동)'],
#  ['서울특별시 송파구 마천동 성내천로37길 37'],
#  ['서울특별시 송파구 신천동 29-5 송파구청 앞'],
#  ['서울특별시 송파구 송파동 오금로32길 14'],
#  ['서울특별시 송파구 가락동 154'],
#  ['서울특별시 강동구 둔촌동 522-9'],
#  ['서울특별시 강동구 강일동 아리수로93길 40'],
#  ['서울특별시 송파구 양재대로 932'],
#  ['서울특별시 강동구 둔촌동 명일로 102'],
#  ['서울특별시 송파구 잠실동 40'],
#  ['서울특별시 송파구 장지동 516'],
#  ['서울특별시 강동구 구천면로 42길 60', '천호동)'],
#  ['서울특별시 송파구 잠실동 잠실로 88'],
#  ['서울특별시 송파구 올림픽로 135'],
#  ['서울특별시 강동구 성내동 풍성로 128'],
#  ['서울특별시 강동구 천호동 천호대로 1089'],
#  ['서울특별시 송파구 거여동 양산로4길 8'],
#  ['서울특별시 송파구 거여동 195-1'],
#  ['서울특별시 송파구 위례광장로 163 ', '장지동'],
#  ['서울특별시 송파구 신천동 7-11'],
#  ['서울특별시 강동구 명일동 260-1'],
#  ['서울특별시 송파구 송파동 오금로32길 14'],
#  ['서울특별시 송파구 잠실동 잠실로 88'],
#  ['서울특별시 강동구 고덕동 동남로79길 26'],
#  ['서울특별시 송파구 가락동 동남로 193'],
#  ['서울특별시 송파구 충민로6길 14'],
#  ['서울특별시 송파구 송파대로 8길 17'],
#  ['서울특별시 송파구 풍납동 403-11'],
#  ['서울특별시 송파구 신천동 올림픽로 269'],
#  ['서울특별시 송파구 거여동 양산로4길 16'],
#  ['서울특별시 송파구 올림픽로 135'],
#  ['서울특별시 강동구 상일로 74'],
#  ['서울특별시 강동구 양재대로 1571'],
#  ['서울특별시 송파구 가락동 송파대로28길 27'],
#  ['서울특별시 송파구 장지동 위례광장로 215'],
#  ['서울특별시 송파구 충민로 4길 19'],
#  ['서울특별시 송파구 올림픽로35길 93'],
#  ['서울특별시 강동구 천호대로168길 58'],
#  ['서울특별시 강동구 올림픽로 664'],
#  ['서울특별시 송파구 송파대로 8길 17'],
#  ['서울특별시 송파구 마천동 성내천로47길 38'],
#  ['서울특별시 송파구 성내천로43길 6'],
#  ['서울특별시 송파구 장지동 충민로4길 5'],
#  ['서울특별시 송파구 충민로6길 14'],
#  ['서울특별시 강동구 천호대로 1239', '길동)'],
#  ['서울특별시 송파구 장지동 위례광장로 215'],
#  ['서울특별시 송파구 삼전동 175-8'],
#  ['서울특별시 송파구 장지동 380-1'],
#  ['서울특별시 강동구 아리수로98길 25'],
#  ['서울특별시 강동구 강일동 아리수로97길 20'],
#  ['서울특별시 송파구 마천동 성내천로37길 37'],
#  ['서울특별시 송파구 문정로 지하 12'],
#  ['서울특별시 송파구 가락동 송파대로28길 27'],
#  ['서울특별시 송파구 백제고분로 187'],
#  ['서울특별시 송파구 위례광장로 163 ', '장지동'],
#  ['서울특별시 송파구 문정동 문정로 83'],
#  ['서울특별시 강동구 천호대로 1005'],
#  ['서울특별시 송파구 거여동 양산로8길 8'],
#  ['서울특별시 송파구 가락동 동남로 193'],
#  ['서울특별시 송파구 거여동 양산로8길 8'],
#  ['서울특별시 송파구 방이동 양재대로 1089'],
#  ['서울특별시 송파구 장지동 380-1'],
#  ['서울특별시 송파구 잠실동 40'],
#  ['서울특별시 강동구 올림픽로91길 30 ', '암사동'],
#  ['서울특별시 송파구 장지동 516'],
#  ['서울특별시 송파구 장지동 위례광장로 270'],
#  ['서울특별시 강동구 강일동 아리수로97길 20'],
#  ['서울특별시 강동구 둔촌동 명일로 172'],
#  ['서울특별시 송파구 마천동 성내천로47길 38'],
#  ['서울특별시 강동구 양재대로95길 53 ', '성내동'],
#  ['서울특별시 강동구 강일동 아리수로94길 19'],
#  ['서울특별시 송파구 백제고분로44길 13-25'],
#  ['서울특별시 강동구 천호대로 1239', '길동)'],
#  ['서울특별시 송파구 장지동 송파대로8길 20'],
#  ['서울특별시 송파구 장지동 833'],
#  ['서울특별시 송파구 풍납동 토성로 38-6'],
#  ['서울특별시 강동구 둔촌동 명일로 110'],
#  ['서울특별시 송파구 풍납동 토성로 38-6'],
#  ['서울특별시 강동구 길동 명일로 293'],
#  ['서울특별시 강동구 성내동 풍성로 128'],
#  ['서울특별시 강동구 상일로 152'],
#  ['서울특별시 강동구 둔촌동 명일로 172'],
#  ['서울특별시 강동구 상일로 74'],
#  ['서울특별시 송파구 풍납동 올림픽로47길 9'],
#  ['서울특별시 강동구 길동 명일로 293'],
#  ['서울특별시 강동구 둔촌동 522-9'],
#  ['서울특별시 강동구 고덕동 동남로79길 26'],
#  ['서울특별시 강동구 강일동 아리수로93길 40'],
#  ['서울특별시 강동구 명일동 동남로71길 19'],
#  ['서울특별시 강동구 성내동 541-2'],
#  ['서울특별시 송파구 거여동 양산로4길 8'],
#  ['서울특별시 송파구 장지동 위례광장로 185'],
#  ['서울특별시 송파구 거여동 양산로4길 16'],
#  ['서울특별시 강동구 아리수로98길 25'],
#  ['서울특별시 송파구 장지동 송파대로8길 20'],
#  ['서울특별시 송파구 신천동 올림픽로 269'],
#  ['서울특별시 강동구 강일동 고덕로97길 100'],
#  ['서울특별시 송파구 장지동 충민로4길 5'],
#  ['서울특별시 강동구 강일동 고덕로97길 20'],
#  ['서울특별시 강동구 암사동 올림픽로104길 41'],
#  ['서울특별시 강동구 암사동 고덕로 53'],
#  ['서울특별시 강동구 암사동 올림픽로104길 41'],
#  ['서울특별시 강동구 천호동 천호대로 1089'],
#  ['서울특별시 강동구 둔촌동 명일로 102'],
#  ['서울특별시 송파구 풍납동 풍성로26길 31'],
#  ['서울특별시 강동구 성내동 풍성로53길 40'],
#  ['서울특별시 송파구 풍납동 올림픽로47길 9'],
#  ['서울특별시 송파구 문정동 문정로 83'],
#  ['서울특별시 송파구 충민로 4길 19'],
#  ['서울특별시 송파구 오금로62길 10'],
#  ['서울특별시 송파구 가락동 중대로12길 35'],
#  ['서울특별시 강동구 암사동 고덕로19길 30'],
#  ['서울특별시 강동구 선사로 70 ', '천호동)'],
#  ['서울특별시 송파구 동남로 263 ', '오금동'],
#  ['서울특별시 강동구 동남로 870 ', '상일동'],
#  ['서울특별시 영등포구 문래동3가 문래로 82'],
#  ['서울특별시 영등포구 여의도동 의사당대로 127'],
#  ['서울특별시 영등포구 도림동 도영로 66'],
#  ['서울특별시 영등포구 대림동 870'],
#  ['서울특별시 영등포구 문래동3가 당산로4길 12'],
#  ['서울특별시 영등포구 문래동3가 80'],
#  ['서울특별시 영등포구 영등포로 351'],
#  ['서울특별시 영등포구 여의도동 21'],
#  ['서울특별시 영등포구 당산동2가 16-1'],
#  ['서울특별시 영등포구 여의도동 1'],
#  ['서울특별시 영등포구 신길동 가마산로 540'],
#  ['서울특별시 영등포구 신길동 신길로 119'],
#  ['서울특별시 영등포구 신길동 대방천로14길 34'],
#  ['서울특별시 영등포구 신길동 가마산로79길 7'],
#  ['서울특별시 영등포구 대림동 608-1'],
#  ['서울특별시 영등포구 문래동3가 당산로4길 12'],
#  ['서울특별시 영등포구 신길동 가마산로79길 7'],
#  ['서울특별시 영등포구 양평동5가 76'],
#  ['서울특별시 영등포구 대림동 780'],
#  ['서울특별시 영등포구 신길동 4945'],
#  ['서울특별시 영등포구 문래동3가 97'],
#  ['서울특별시 영등포구 양평동5가 76'],
#  ['서울특별시 영등포구 문래동3가 93-1'],
#  ['서울특별시 영등포구 여의도동 21'],
#  ['서울특별시 영등포구 문래동3가 80'],
#  ['서울특별시 영등포구 여의도동 의사당대로 127'],
#  ['서울특별시 영등포구 영등포로 351'],
#  ['서울특별시 영등포구 신길동 4945'],
#  ['서울특별시 영등포구 당산동2가 16-1'],
#  ['서울특별시 영등포구 도림동 도영로 66'],
#  ['서울특별시 영등포구 대림동 608-1'],
#  ['서울특별시 영등포구 당산로27길 12 ', '당산동3가)'],
#  ['서울특별시 영등포구 선유동2로 6 ', '당산동4가'],
#  ['서울특별시 영등포구 국회대로 596 ', '당산동3가'],
#  nan,
#  ['서울특별시 양천구 신정로11길 20 ', '신정동'],
#  ['서울특별시 강서구 방화동 금낭화로 287-19'],
#  ['서울특별시 강서구 공항대로 583'],
#  ['서울특별시 양천구 신정이펜2로 55'],
#  ['서울특별시 양천구 목동 961'],
#  ['서울특별시 양천구 목동 908-28'],
#  ['서울특별시 강서구 마곡동 725-1'],
#  ['서울특별시 강서구 방화동 886'],
#  ['서울특별시 양천구 목동 900'],
#  ['서울특별시 강서구 마곡동 736'],
#  ['서울특별시 강서구 방화동 금낭화로23길 8'],
#  ['서울특별시 양천구 신정동 중앙로36길 15'],
#  ['서울특별시 강서구 내발산동 742'],
#  ['서울특별시 양천구 신월동 1026'],
#  ['서울특별시 강서구 화곡동 1139'],
#  ['서울특별시 강서구 내발산동 751'],
#  ['서울특별시 강서구 수명로2길 108'],
#  ['서울특별시 강서구 마곡동 743'],
#  ['서울특별시 강서구 마곡동 마곡서1로 146'],
#  ['서울특별시 양천구 신정동 319-1'],
#  ['서울특별시 강서구 마곡동 748'],
#  ['서울특별시 강서구 내발산동 749'],
#  ['서울특별시 강서구 내발산동 749'],
#  ['서울특별시 강서구 방화동 금낭화로 287-19'],
#  ['서울특별시 양천구 목동 905-22'],
#  ['서울특별시 강서구 마곡동 공항대로 124'],
#  ['서울특별시 강서구 내발산동 수명로2길 63'],
#  ['서울특별시 강서구 마곡동 736'],
#  ['서울특별시 양천구 신정동 337'],
#  ['서울특별시 강서구 마곡동 725-1'],
#  ['서울특별시 양천구 신월동 263'],
#  ['서울특별시 양천구 목동 961'],
#  ['서울특별시 강서구 마곡동 748'],
#  ['서울특별시 강서구 방화동 875'],
#  ['서울특별시 강서구 마곡동 743'],
#  ['서울특별시 강서구 마곡동 마곡서1로 81'],
#  ['서울특별시 양천구 신정동 1324'],
#  ['서울특별시 양천구 신정동 중앙로36길 15'],
#  ['서울특별시 양천구 신정동 1281'],
#  ['서울특별시 강서구 내발산동 수명로2가길 22'],
#  ['서울특별시 강서구 가양동 양천로55길 55'],
#  ['서울특별시 강서구 공항대로 351-21 ', '등촌동'],
#  ['서울특별시 양천구 신정동 318-10'],
#  ['서울특별시 강서구 염창동 306'],
#  ['서울특별시 양천구 목동 755-1'],
#  ['서울특별시 강서구 공항대로59길 64'],
#  ['서울특별시 강서구 가양동 양천로55길 55'],
#  ['서울특별시 양천구 신월동 남부순환로56길 9'],
#  ['서울특별시 양천구 신월동 506-1'],
#  ['서울특별시 양천구 신정동 319-1'],
#  ['서울특별시 양천구 신월로20길 7'],
#  ['서울특별시 양천구 신정동 1281'],
#  ['서울특별시 양천구 신월동 1026'],
#  ['서울특별시 강서구 내발산동 751'],
#  ['서울특별시 강서구 내발산동 수명로2길 63'],
#  ['서울특별시 양천구 신월동 217-8'],
#  ['서울특별시 강서구 내발산동 수명로2가길 22'],
#  ['서울특별시 강서구 마곡서1로 48 ', '마곡동'],
#  ['서울특별시 양천구 목동 905-22'],
#  ['서울특별시 양천구 신정동 318-10'],
#  ['서울특별시 강서구 내발산동 742'],
#  ['서울특별시 강서구 마곡중앙4로 74 ', '마곡동)'],
#  ['서울특별시 양천구 목동동로 155 ', '신정동)'],
#  ['서울특별시 양천구 목동중앙북로8다길 지하 4 ', '목동'],
#  ['서울특별시 강서구 공항대로59길 64'],
#  ['서울특별시 강서구 방화동 금낭화로23길 8'],
#  ['서울특별시 양천구 목동동로 233 ', '목동'],
#  ['서울특별시 양천구 신정로11길 20 ', '신정동'],
#  ['서울특별시 양천구 월정로 46 ', '신월동)'],
#  ['서울특별시 강서구 하늘길 78 ', '과해동'],
#  ['서울특별시 강서구 화곡로 308 ', '화곡동'],
#  ['서울특별시 양천구 목동동로 105 ', '신정동'],
#  ['서울특별시 관악구 봉천동 인헌12길 46-1'],
#  ['서울특별시 관악구 신사로 7'],
#  ['서울특별시 동작구 동작동 동작대로39길 22'],
#  ['서울특별시 관악구 봉천동 청룡길 78'],
#  ['서울특별시 동작구 상도동 상도로 346-2'],
#  ['서울특별시 관악구 신림동 난곡로 66'],
#  ['서울특별시 동작구 상도동 상도로60길 20'],
#  ['서울특별시 관악구 봉천동 보라매로 62'],
#  ['서울특별시 관악구 봉천동 인헌12길 46-1'],
#  ['서울특별시 동작구 상도동 장승배기로 11'],
#  ['서울특별시 동작구 동작대로 19'],
#  ['서울특별시 동작구 흑석동 흑석한강로 2'],
#  ['서울특별시 관악구 신림동 호암로16길 5'],
#  ['서울특별시 동작구 대방동 여의대방로44길 9'],
#  ['서울특별시 관악구 봉천동 은천로 93'],
#  ['서울특별시 동작구 신대방동 여의대방로10길 100'],
#  ['서울특별시 동작구 신대방동 여의대방로 28'],
#  ['서울특별시 동작구 신대방동 신대방1가길 38'],
#  ['서울특별시 관악구 신림동 미성길 122'],
#  ['서울특별시 동작구 사당동 사당로27길 190'],
#  ['서울특별시 관악구 봉천동 1701'],
#  ['서울특별시 관악구 신림동 신림로 11길 151'],
#  ['서울특별시 동작구 상도동 장승배기로 11'],
#  ['서울특별시 동작구 신대방동 신대방1가길 38'],
#  ['서울특별시 동작구 동작대로 19'],
#  ['서울특별시 관악구 신림동 광신길 86'],
#  ['서울특별시 관악구 봉천동 은천로33길 5'],
#  ['서울특별시 동작구 상도동 양녕로 287'],
#  ['서울특별시 동작구 동작동 동작대로39길 22'],
#  ['서울특별시 동작구 대방동 345-1'],
#  ['서울특별시 관악구 봉천동 청룡길 78'],
#  ['서울특별시 동작구 상도동 상도로 346-2'],
#  ['서울특별시 관악구 신림동 미성길 122'],
#  ['서울특별시 관악구 신림동 미성3길 16'],
#  ['서울특별시 동작구 대방동 상도로 53길 8'],
#  ['서울특별시 관악구 신림로3가길 45-24'],
#  ['서울특별시 동작구 신대방동 보라매로5가길 16'],
#  ['서울특별시 동작구 대방동 상도로 53길 8'],
#  ['서울특별시 관악구 봉천동 은천로33길 5'],
#  ['서울특별시 동작구 신대방동 여의대방로 28'],
#  ['서울특별시 동작구 상도동 등용로 37'],
#  ['서울특별시 관악구 봉천동 보라매로 62'],
#  ['서울특별시 동작구 상도동 등용로 37'],
#  ['서울특별시 동작구 대방동 여의대방로44길 9'],
#  ['서울특별시 동작구 흑석동 흑석한강로 2'],
#  ['서울특별시 관악구 남부순환로 1546 ', '신림동'],
#  ['서울특별시 동작구 사당동 사당로27길 190'],
#  ['서울특별시 동작구 국사봉16길 28 ', '상도동'],
#  ['서울특별시 관악구 낙성대로3길 37 ', '봉천동'],
#  ['서울특별시 동작구 노량진로 47 ', '대방동'],
#  ['서울특별시 서초구 방배동 755-14'],
#  ['서울특별시 서초구 우면동 735'],
#  ['서울특별시 서초구 우면동 737'],
#  ['서울특별시 서초구 효령로 72길 60'],
#  ['서울특별시 서초구 신원동 374'],
#  ['서울특별시 서초구 서초동 1301-6'],
#  ['서울특별시 서초구 반포동 30-26'],
#  ['서울특별시 서초구 서초동 산 130-19'],
#  ['서울특별시 null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null'],
#  ['서울특별시 서초구 신원동 374'],
#  ['서울특별시 서초구 서초동 1681-8'],
#  ['서울특별시 서초구 방배동 774-19'],
#  ['서울특별시 서초구 서초동 1456-2'],
#  ['서울특별시 서초구 방배동 772-13'],
#  ['경기도 과천시 별양동 별양로 163'],
#  ['서울특별시 서초구 우면동 368-1'],
#  ['서울특별시 서초구 우면동 753'],
#  ['서울특별시 서초구 방배동 3275'],
#  ['서울특별시 서초구 우면동 773'],
#  ['서울특별시 서초구 반포동 2-12'],
#  ['서울특별시 서초구 내곡동 77'],
#  ['서울특별시 서초구 내곡동 6-7'],
#  ['서울특별시 서초구 우면동 788'],
#  ['서울특별시 서초구 내곡동 77'],
#  ['서울특별시 서초구 우면동 773'],
#  ['서울특별시 서초구 우면동 753'],
#  ['서울특별시 서초구 반포동 동광로32길 7'],
#  ['서울특별시 서초구 서초동 1542-1'],
#  ['서울특별시 서초구 반포동 19-3'],
#  ['서울특별시 서초구 방배동 797-30'],
#  ['서울특별시 서초구 서초동 1529'],
#  ['서울특별시 서초구 우면동 707'],
#  ['서울특별시 서초구 방배동 884-2'],
#  ['서울특별시 서초구 우면동 763'],
#  ['서울특별시 서초구 방배동 754-1'],
#  ['서울특별시 서초구 반포동 60-4'],
#  ['서울특별시 서초구 서초동 1642-14'],
#  ['서울특별시 서초구 우면동 737'],
#  ['서울특별시 서초구 방배동 3277'],
#  ['서울특별시 서초구 우면동 368-1'],
#  ['서울특별시 서초구 방배동 844-1'],
#  ['서울특별시 서초구 효령로 72길 60'],
#  ['서울특별시 서초구 방배동 754-1'],
#  ['서울특별시 서초구 반포동 30-26'],
#  ['서울특별시 서초구 반포동 산 94-1'],
#  ['서울특별시 서초구 서초동 1301-6'],
#  ['서울특별시 서초구 반포대로22길 86'],
#  ['서울특별시 서초구 서초동 1642-34'],
#  ['서울특별시 null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null'],
#  ['서울특별시 서초구 잠원로3길 40'],
#  ['서울특별시 서초구 주흥5길 20 ', '반포동)'],
#  ['서울특별시 서초구 잠원동 10-33'],
#  ['서울특별시 서초구 서초동 1444-19'],
#  ['서울특별시 서초구 서초동 1338'],
#  ['서울특별시 서초구 서초동 1549-3'],
#  ['서울특별시 서초구 양재동 399'],
#  ['서울특별시 서초구 강남대로8길 77 ', '양재동'],
#  ['서울특별시 서초구 헌릉로 13 ', '염곡동'],
#  ['서울특별시 서초구 동작대로 22-2 ', '방배동'],
#  ['서울특별시 서초구 헌릉로 25 ', '염곡동'],
#  ['서울특별시 서초구 매헌로 16 ', '양재동'],
#  ['경기도 과천시 중앙로 294 ', '관문동'],
#  ['경기도 과천시 문원로 56 ', '문원동'],
#  ['경기도 과천시 통영로 5 ', '중앙동'],
#  ['경기도 과천시 용마로 13 ', '과천동'],
#  ['경기도 과천시 과천대로 608-17 ', '과천동'],
#  ['경기도 과천시 대공원광장로 102 ', '막계동'],
#  ['서울특별시 강남구 자곡동 자곡로 175'],
#  ['서울특별시 강남구 도곡동 언주로30길 56'],
#  ['서울특별시 강남구 역삼동 757'],
#  ['서울특별시 강남구 역삼동 757'],
#  ['서울특별시 강남구 역삼동 755-1'],
#  ['서울특별시 강남구 역삼동 역삼로 306'],
#  ['서울특별시 강남구 세곡동 533'],
#  ['서울특별시 강남구 대치동 도곡로93길 12'],
#  ['서울특별시 강남구 신사동 압구정로42길 78'],
#  ['서울특별시 강남구 자곡동 자곡로3길 21'],
#  ['서울특별시 강남구 도곡동 선릉로 221'],
#  ['서울특별시 강남구 도곡동 언주로30길 26'],
#  ['서울특별시 강남구 자곡동 자곡로 260'],
#  ['서울특별시 강남구 세곡동 헌릉로590길 63'],
#  ['서울특별시 강남구 삼성동 16-1'],
#  ['서울특별시 강남구 율현동 밤고개로26길 50'],
#  ['서울특별시 강남구 영동대로65길 24'],
#  ['서울특별시 강남구 선릉로 121길 12'],
#  ['서울특별시 강남구 청담동 학동로97길 31'],
#  ['서울특별시 강남구 일원동 일원로 127'],
#  ['서울특별시 강남구 자곡동 자곡로3길 21'],
#  ['서울특별시 강남구 일원동 일원로 120'],
#  ['서울특별시 강남구 언주로 211'],
#  ['서울특별시 중랑구 상봉동 봉화산로 130'],
#  ['서울특별시 동대문구 전농동 사가정로 148'],
#  ['서울특별시 중랑구 면목동 1081-1'],
#  ['서울특별시 동대문구 휘경동 망우로20길 86'],
#  ['서울특별시 중랑구 상봉동 상봉중앙로1다길 21'],
#  ['서울특별시 중랑구 동일로 862'],
#  nan,
#  ['서울특별시 동대문구 장안동 장안벚꽃로1길 7'],
#  ['서울특별시 동대문구 답십리동 한천로37길 33'],
#  nan,
#  ['서울특별시 동대문구 휘경동 한천로 248'],
#  ['서울특별시 동대문구 회기동 1-1'],
#  ['서울특별시 중랑구 묵동 동일로 932'],
#  ['서울특별시 동대문구 답십리동 한천로37길 33'],
#  ['서울특별시 중랑구 상봉동 망우로 346'],
#  ['서울특별시 중랑구 면목동 동일로 483'],
#  ['서울특별시 동대문구 전농로10길 20'],
#  ['서울특별시 동대문구 한천로 300'],
#  ['서울특별시 중랑구 신내동 신내역로1길 85'],
#  ['서울특별시 동대문구 답십리로 130'],
#  ['서울특별시 중랑구 묵동 숙선옹주로 6-9'],
#  ['서울특별시 중랑구 상봉동 망우로 346'],
#  ['서울특별시 동대문구 답십리로 130'],
#  ['서울특별시 중랑구 신내동 신내로17길 41'],
#  ['서울특별시 중랑구 망우동 양원역로 6'],
#  ['서울특별시 중랑구 봉화산로48길 62'],
#  ['서울특별시 중랑구 묵동 동일로 932'],
#  ['서울특별시 중랑구 상봉동 상봉중앙로1다길 21'],
#  ['서울특별시 중랑구 동일로 862'],
#  ['서울특별시 동대문구 천호대로55길 11 ', '답십리동'],
#  ['서울특별시 중랑구 망우동 망우로75길 19'],
#  ['서울특별시 동대문구 휘경동 장안벚꽃로5길 19'],
#  ['서울특별시 동대문구 답십리로 130'],
#  ['서울특별시 동대문구 전농로10길 20'],
#  ['서울특별시 중랑구 신내동 신내로17길 41'],
#  ['서울특별시 중랑구 묵동 숙선옹주로 6-9'],
#  ['서울특별시 중랑구 신내동 신내역로1길 85'],
#  nan,
#  ['서울특별시 중랑구 상봉동 봉화산로 130'],
#  ['서울특별시 중랑구 중랑역로 9 ', '중화동'],
#  ['서울특별시 중랑구 망우동 망우로75길 19'],
#  ['서울특별시 중랑구 망우로62길 52-4 ', '망우동'],
#  ['서울특별시 중랑구 봉화산로 123 ', '상봉동'],
#  ['서울특별시 동대문구 왕산로 214 ', '전농동'],
#  ['서울특별시 성동구 성수동2가 성수이로 137'],
#  ['서울특별시 광진구 자양동 아차산로 262'],
#  ['서울특별시 광진구 자양로 117'],
#  ['서울특별시 광진구 뚝섬로 52길 74'],
#  ['서울특별시 광진구 자양3동 510-8'],
#  ['서울특별시 성동구 응봉동 고산자로4길 34'],
#  ['서울특별시 광진구 광장동 아차산로 537-17'],
#  ['서울특별시 성동구 왕십리로 410'],
#  ['서울특별시 광진구 광나루로56길 85 ', '구의동'],
#  ['서울특별시 성동구 금호동1가 금호로 140'],
#  ['서울특별시 성동구 행당동 행당로 82'],
#  ['서울특별시 성동구 하왕십리동 843'],
#  ['서울특별시 성동구 금호동2가 금호로 117'],
#  ['서울특별시 성동구 성수동2가 성수이로 137'],
#  ['서울특별시 광진구 자양3동 510-8'],
#  ['서울특별시 광진구 광나루로56길 85 ', '구의동'],
#  ['서울특별시 광진구 광장동 아차산로 537-17'],
#  ['서울특별시 성동구 하왕십리동 674-1'],
#  ['서울특별시 성동구 자동차시장길 49'],
#  ['서울특별시 성동구 금호동4가 금호로 15'],
#  ['서울특별시 성동구 응봉동 고산자로4길 34'],
#  ['서울특별시 성동구 왕십리로 222 ', '사근동)'],
#  ['서울특별시 성동구 왕십리로 410'],
#  ['서울특별시 성동구 금호동2가 금호로 117'],
#  ['서울특별시 광진구 광장로5길 25-1'],
#  ['서울특별시 광진구 구의강변로 106 ', '구의동'],
#  ['서울특별시 성동구 행당동 행당로 82'],
#  ['서울특별시 성동구 마장로27길 13'],
#  ['서울특별시 성동구 마장로27길 13'],
#  ['서울특별시 성동구 왕십리로 410'],
#  ['서울특별시 광진구 구의강변로 106 ', '구의동'],
#  ['서울특별시 광진구 자양동 구의강변로1길 44'],
#  ['서울특별시 성동구 뚝섬로1길 31 ', '성수동1가'],
#  ['서울특별시 광진구 자양동 아차산로36길 13'],
#  ['서울특별시 광진구 자양동 아차산로 262'],
#  ['서울특별시 성동구 왕십리로 410'],
#  ['서울특별시 성동구 하왕십리동 843'],
#  ['서울특별시 성동구 성수동1가 상원6길 16'],
#  ['서울특별시 성동구 하왕십리동 674-1'],
#  ['서울특별시 광진구 자양동 뚝섬로34길 25-19'],
#  ['서울특별시 성동구 금호동1가 금호로 140'],
#  ['서울특별시 성동구 성수일로8길 5 ', '성수동2가'],
#  ['서울특별시 성동구 금호로 20 ', '금호동4가)'],
#  ['서울특별시 성동구 성수동1가 685-63번지'],
#  ['서울특별시 도봉구 창동 도봉로 428'],
#  ['서울특별시 노원구 중계동 덕릉로76길 29'],
#  ['서울특별시 도봉구 창동 노해로69길 103'],
#  ['서울특별시 도봉구 창동 노해로69길 103'],
#  ['서울특별시 도봉구 도봉로 678'],
#  ['서울특별시 노원구 섬밭로 265 ', '중계동'],
#  ['서울특별시 노원구 상계동 701-1'],
#  ['서울특별시 노원구 공릉로 232'],
#  ['서울특별시 도봉구 창동 노해로 403'],
#  ['서울특별시 도봉구 도봉로 552 ', '창동'],
#  ['서울특별시 노원구 화랑로 815'],
#  ['서울특별시 도봉구 창동 마들로 551'],
#  ['서울특별시 도봉구 노해로70길 126 ', '창동'],
#  ['서울특별시 도봉구 창동 도봉로136길 111'],
#  ['서울특별시 도봉구 덕릉로63가길 43 ', '창동'],
#  ['서울특별시 노원구 동일로227길 86 ', '상계동'],
#  ['서울특별시 노원구 상계동 상계로5길 12'],
#  ['서울특별시 노원구 한글비석로 15길 51'],
#  ['서울특별시 도봉구 방학동 해등로 286-5'],
#  ['서울특별시 노원구 하계동 동일로207길 186'],
#  ['서울특별시 도봉구 마들로 616'],
#  ['서울특별시 노원구 중계동 덕릉로76길 29'],
#  ['서울특별시 노원구 중계동 노원로22길 34'],
#  ['서울특별시 도봉구 우이천로 367'],
#  ['서울특별시 노원구 덕릉로70가길 21 ', '상계동'],
#  ['서울특별시 도봉구 도봉동 도봉산길 35'],
#  ['서울특별시 도봉구 시루봉로 11길 25-8'],
#  ['서울특별시 도봉구 창동 노해로 403'],
#  ['서울특별시 도봉구 마들로 656 ', '방학동'],
#  ['서울특별시 노원구 공릉동 화랑로51길 17'],
#  ['서울특별시 노원구 공릉동 670-20'],
#  ['서울특별시 도봉구 쌍문동 388-1'],
#  ['서울특별시 노원구 상계동 652'],
#  ['서울특별시 노원구 월계동 석계로13길 35'],
#  ['서울특별시 노원구 상계동 덕릉로 780'],
#  ['서울특별시 도봉구 도봉동 도봉로180길 6-23'],
#  ['서울특별시 노원구 중계동 중계로 195'],
#  ['서울특별시 도봉구 방학동 방학로12길 53'],
#  ['서울특별시 노원구 공릉동 동일로195길 39'],
#  ['서울특별시 노원구 상계동 동일로250길 18'],
#  ['서울특별시 노원구 동일로183길 34'],
#  ['서울특별시 도봉구 마들로 684-20'],
#  ['서울특별시 노원구 동일로227길 86 ', '상계동'],
#  ['서울특별시 도봉구 창동 도봉로136길 111'],
#  ['서울특별시 노원구 공릉동 공릉로 213'],
#  ['서울특별시 노원구 상계동 상계로5길 12'],
#  ['서울특별시 도봉구 마들로 735-8'],
#  ['서울특별시 노원구 노원로22길 71 ', '중계동'],
#  ['서울특별시 노원구 노원로22길 71 ', '중계동'],
#  ['서울특별시 노원구 공릉동 91'],
#  ['서울특별시 노원구 공릉동 화랑로51길 17'],
#  ['서울특별시 노원구 동일로 1238 ', '중계동'],
#  ['서울특별시 노원구 월계동 초안산로 89'],
#  ['서울특별시 노원구 월계동 화랑로 355'],
#  ['서울특별시 노원구 공릉동 화랑로51길 78'],
#  ['서울특별시 도봉구 방학동 방학로 200'],
#  ['서울특별시 도봉구 마들로 735-8'],
#  ['서울특별시 도봉구 창동 덕릉로60바길 21'],
#  ['서울특별시 도봉구 시루봉로 58'],
#  ['서울특별시 도봉구 도봉동 도봉로180길 6-23'],
#  ['서울특별시 노원구 월계동 초안산로 89'],
#  ['서울특별시 노원구 중계동 덕릉로 613'],
#  ['서울특별시 노원구 노해로 429 ', '상계동'],
#  ['서울특별시 도봉구 방학동 도봉로150길 43'],
#  ['서울특별시 도봉구 마들로 616'],
#  ['서울특별시 노원구 상계동 누원로 28'],
#  ['서울특별시 도봉구 방학동 도봉로150바길 26'],
#  ['서울특별시 도봉구 시루봉로2길 62 ', '쌍문동'],
#  ['서울특별시 노원구 공릉동 공릉로 206'],
#  ['서울특별시 노원구 중계동 노원로22길 34'],
#  ['서울특별시 노원구 공릉동 화랑로51길 78'],
#  ['서울특별시 노원구 상계동 누원로 28'],
#  ['서울특별시 노원구 상계동 덕릉로 780'],
#  ['서울특별시 도봉구 도봉동 도봉산길 35'],
#  ['서울특별시 노원구 하계동 동일로207길 186'],
#  ['서울특별시 도봉구 방학동 방학로 200'],
#  ['서울특별시 도봉구 창동 도봉로 642-30'],
#  ['서울특별시 도봉구 방학동 방학로11길 33'],
#  ['서울특별시 노원구 공릉동 공릉로 213'],
#  ['서울특별시 노원구 공릉동 섬밭로 52'],
#  ['서울특별시 노원구 공릉동 동일로175길 38'],
#  ['서울특별시 노원구 상계동 상계로7길 18'],
#  ['서울특별시 노원구 상계동 한글비석로52길 66'],
#  ['서울특별시 노원구 상계동 한글비석로52길 66'],
#  ['서울특별시 도봉구 시루봉로 58'],
#  ['서울특별시 노원구 공릉동 섬밭로 156'],
#  ['서울특별시 도봉구 우이천로 367'],
#  ['서울특별시 도봉구 시루봉로 6길53'],
#  ['서울특별시 도봉구 덕릉로 60길 164-13'],
#  ['서울특별시 도봉구 창동 우이천로20길 6'],
#  ['서울특별시 도봉구 쌍문동 우이천로30길 28'],
#  ['서울특별시 도봉구 덕릉로 60길 164-13'],
#  ['서울특별시 노원구 중계동 중계로14나길 25'],
#  ['서울특별시 노원구 중계동 중계로14나길 25'],
#  ['서울특별시 노원구 공릉동 섬밭로 139'],
#  ['서울특별시 노원구 공릉동 섬밭로 139'],
#  ['서울특별시 노원구 중계동 중계로8길 39'],
#  ['서울특별시 노원구 중계동 중계로 195'],
#  ['서울특별시 노원구 노원로 75 ', '공릉동'],
#  ['서울특별시 도봉구 방학동 해등로 286-5'],
#  ['서울특별시 노원구 공릉동 공릉로27길 110'],
#  ['서울특별시 노원구 노해로 429 ', '상계동'],
#  ['서울특별시 도봉구 방학로10길 51 ', '방학동'],
#  ['서울특별시 도봉구 시루봉로 94 ', '방학동'],
#  ['서울특별시 도봉구 덕릉로62길 89 ', '창동'],
#  ['서울특별시 서대문구 홍은중앙로 125'],
#  ['서울특별시 서대문구 북가좌동 481'],
#  ['서울특별시 은평구 백련산로 90'],
#  ['서울특별시 은평구 진관동 65-31'],
#  ['서울특별시 서대문구 연희동 739'],
#  ['서울특별시 서대문구 북가좌동 481'],
#  ['서울특별시 서대문구 남가좌동 377'],
#  ['서울특별시 서대문구 증가로 150 ', '남가좌동'],
#  ['서울특별시 서대문구 연세로 50 ', '신촌동'],
#  ['서울특별시 은평구 불광천길 436 ', '응암동'],
#  ['서울특별시 서대문구 홍제동 통일로 397'],
#  ['서울특별시 은평구 진관동 진관2로 57-7'],
#  ['서울특별시 은평구 녹번동 153-1'],
#  ['서울특별시 서대문구 독립문로14길 33'],
#  ['서울특별시 은평구 통일로 1034 ', '진관동'],
#  ['서울특별시 서대문구 남가좌동 377'],
#  ['서울특별시 서대문구 연희로32길 48 ', '연희동'],
#  ['서울특별시 은평구 통일로 659'],
#  ['서울특별시 서대문구 통일로26길 41 ', '홍제동'],
#  ['서울특별시 은평구 통일로 659'],
#  ['서울특별시 서대문구 북가좌동 거북골로14길 32'],
#  ['서울특별시 은평구 진관동 진관2로 57-7'],
#  ['서울특별시 은평구 연서로 78 ', '역촌동)'],
#  ['서울특별시 서대문구 독립문로14길 33'],
#  ['서울특별시 서대문구 홍제동 통일로 344'],
#  ['서울특별시 서대문구 연세로 50-1 ', '신촌동'],
#  ['서울특별시 서대문구 연희동 736'],
#  ['서울특별시 마포구 월드컵로 243-48 ', '성산동'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 용산구 이촌동 이촌로 300'],
#  ['서울특별시 마포구 성산로 128 ', '성산동'],
#  ['서울특별시 용산구 한강로3가 12'],
#  ['서울특별시 마포구 상암동 월드컵로 338'],
#  ['서울특별시 마포구 신공덕동 백범로 230'],
#  ['서울특별시 마포구 도화동 큰우물로 75'],
#  ['서울특별시 용산구 한강대로 211 ', '한강로1가'],
#  ['서울특별시 용산구 이촌동 이촌로64길 15'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 용산구 문배동 백범로90길 26'],
#  ['서울특별시 용산구 한강대로 205 ', '한강로1가'],
#  ['서울특별시 용산구 이촌로 100-8'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 용산구 문배동 청파로 213'],
#  ['서울특별시 마포구 양화로 45'],
#  ['서울특별시 용산구 원효로1가 백범로 341'],
#  ['서울특별시 마포구 신촌로 150 ', '노고산동'],
#  ['서울특별시 마포구 만리재로 36 ', '신공덕동'],
#  ['서울특별시 용산구 한강대로23길 55 ', '한강로3가'],
#  ['서울특별시 용산구 한강대로23길 55 ', '한강로3가'],
#  ['서울특별시 용산구 이촌동 이촌로64길 15'],
#  ['서울특별시 마포구 공덕동 백범로 152'],
#  ['서울특별시 용산구 용산동5가 서빙고로 67'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 용산구 원효로1가 원효로90길 11'],
#  ['서울특별시 용산구 이촌동 이촌로 300'],
#  ['서울특별시 마포구 공덕동 마포대로 109'],
#  ['서울특별시 마포구 용강동 토정로31길 23'],
#  ['서울특별시 용산구 한남대로 80'],
#  ['서울특별시 마포구 월드컵로3길 14 ', '합정동'],
#  ['서울특별시 마포구 토정로37길 38'],
#  ['서울특별시 용산구 삼개로 60 ', '청암동'],
#  ['서울특별시 마포구 월드컵로1길 14 ', '합정동'],
#  ['서울특별시 마포구 도화동 삼개로 38'],
#  ['서울특별시 용산구 이촌동 이촌로 181'],
#  ['서울특별시 마포구 용강동 토정로31길 24'],
#  ['서울특별시 마포구 상수동 독막로20나길 22'],
#  ['서울특별시 용산구 이촌동 이촌로 181'],
#  ['서울특별시 마포구 공덕동 백범로 152'],
#  ['서울특별시 마포구 상수동 독막로20나길 22'],
#  ['서울특별시 마포구 월드컵로 243-48 ', '성산동'],
#  ['서울특별시 용산구 한남동 서빙고로 413'],
#  ['서울특별시 용산구 이촌로 100-8'],
#  ['서울특별시 마포구 상암동 월드컵로 338'],
#  ['서울특별시 용산구 이태원로 29'],
#  ['서울특별시 용산구 한강로3가 서빙고로 35'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 마포구 토정동 토정로32길 11'],
#  ['서울특별시 마포구 양화로 45'],
#  ['서울특별시 마포구 상수동 독막로20나길 21'],
#  ['서울특별시 용산구 용산동5가 서빙고로 67'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 마포구 토정로37길 38'],
#  ['서울특별시 마포구 상수동 독막로20나길 21'],
#  ['서울특별시 마포구 창전동 서강로 95'],
#  ['서울특별시 용산구 문배동 백범로90길 74'],
#  ['서울특별시 마포구 신촌로 150 ', '노고산동'],
#  ['서울특별시 용산구 삼개로 60 ', '청암동'],
#  ['서울특별시 마포구 아현동 마포대로 195'],
#  ['서울특별시 마포구 마포대로 201'],
#  ['서울특별시 마포구 서강대길 40 ', '대흥동'],
#  ['서울특별시 용산구 백범로 341'],
#  ['서울특별시 마포구 용강동 마포대로1길 21'],
#  ['서울특별시 용산구 서빙고로 137'],
#  ['서울특별시 마포구 신공덕동 만리재로 60'],
#  ['서울특별시 마포구 용강동 토정로31길 23'],
#  ['서울특별시 마포구 용강동 토정로31길 24'],
#  ['서울특별시 마포구 토정동 토정로32길 11'],
#  ['서울특별시 마포구 마포동 마포대로 6'],
#  ['서울특별시 용산구 원효로1가 원효로90길 11'],
#  ['서울특별시 용산구 문배동 청파로 213'],
#  ['서울특별시 용산구 문배동 백범로90길 38'],
#  ['서울특별시 용산구 용산동2가 녹사평대로 245'],
#  ['서울특별시 마포구 연남동 동교로39길 11'],
#  ['서울특별시 마포구 도화동 삼개로 38'],
#  ['서울특별시 마포구 토정로 56 ', '합정동)'],
#  ['서울특별시 마포구 마포대로 174 ', '공덕동'],
#  ['서울특별시 마포구 마포대로 163 ', '공덕동'],
#  ['서울특별시 중구 소파로 83 ', '회현동1가'],
#  ['서울특별시 종로구 사직동 사직로8길 4'],
#  ['서울특별시 중구 남대문로 92'],
#  ['서울특별시 중구 순화동 서소문로9길 28'],
#  ['서울특별시 종로구 무악동 통일로 246-20'],
#  ['서울특별시 null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null'],
#  ['서울특별시 종로구 종로5길 58'],
#  ['서울특별시 중구 소공로 35'],
#  ['서울특별시 종로구 구기동 비봉2길 32'],
#  ['서울특별시 중구 소공로 46'],
#  ['서울특별시 중구 세종대로 110 ', '태평로1가'],
#  ['서울특별시 종로구 인의동 종로 183'],
#  ['서울특별시 중구 만리동1가 231'],
#  ['서울특별시 중구 다산로 32 1동'],
#  ['서울특별시 중구 소공로 63 ', '충무로1가'],
#  ['서울특별시 종로구 명륜2가 창경궁로 265'],
#  ['서울특별시 중구 황학동 청계천로 400'],
#  ['서울특별시 종로구 명륜2가 창경궁로 265'],
#  ['서울특별시 종로구 창신동 낙산길 198'],
#  ['서울특별시 중구 다동 85-4'],
#  ['서울특별시 종로구 숭인동 동망산길 47'],
#  ['서울특별시 중구 충무로4가 퇴계로 235'],
#  ['서울특별시 종로구 창신동 낙산길 198'],
#  ['서울특별시 중구 소공로 46'],
#  ['서울특별시 중구 남대문로 92'],
#  ['서울특별시 중구 다산로 32 1동'],
#  ['서울특별시 종로구 무악동 통일로 246-20'],
#  ['서울특별시 중구 황학동 청계천로 400'],
#  ['서울특별시 null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null null'],
#  ['서울특별시 종로구 무악동 통일로 246-20'],
#  ['서울특별시 종로구 창신동 지봉로5길 7'],
#  ['서울특별시 종로구 창신동 지봉로 87'],
#  ['서울특별시 종로구 창신동 지봉로5길 7'],
#  ['서울특별시 종로구 숭인동 종로 347'],
#  ['서울특별시 종로구 사직동 사직로8길 4'],
#  ['서울특별시 종로구 내수동 사직로8길 34'],
#  ['서울특별시 중구 장충단로 59 ', '장충동2가'],
#  ['서울특별시 중구 명동11길 19 ', '명동1가'],
#  ['서울특별시 중구 퇴계로45길 32-12 ', '충무로5가'],
#  ['서울특별시 중구 동호로8다길 22 ', '신당동'],
#  ['서울특별시 종로구 삼일대로19길 5 ', '관철동)'],
#  ['서울특별시 종로구 삼일대로19길 5 ', '관철동)'],
#  ['서울특별시 중구 한강대로 405 ', '봉래동2가'],
#  ['서울특별시 강북구 강북구 도봉로 242'],
#  ['서울특별시 성북구 정릉동 솔샘로24길 15'],
#  ['서울특별시 성북구 솔샘로25길 28 ', '정릉동'],
#  ['서울특별시 성북구 안암로 145'],
#  ['서울특별시 성북구 정릉로 404'],
#  ['서울특별시 성북구 석관동 화랑로48길 16'],
#  ['서울특별시 성북구 하월곡동 종암로 167'],
#  ['서울특별시 성북구 돌곶이로8길 22 ', '석관동'],
#  ['서울특별시 강북구 강북구 도봉로 242'],
#  ['서울특별시 성북구 보문로29다길 31 ', '삼선동2가'],
#  ['서울특별시 성북구 정릉동 북악산로 851'],
#  ['서울특별시 성북구 안암로 145'],
#  ['서울특별시 성북구 장월로1길 28'],
#  ['서울특별시 성북구 솔샘로25길 28 ', '정릉동'],
#  ['서울특별시 성북구 삼선동2가 낙산길 243-15'],
#  ['서울특별시 강북구 미아동 삼양로 256'],
#  ['서울특별시 성북구 삼선교로16길 35 ', '삼선동3가'],
#  ['서울특별시 성북구 북악산로 844'],
#  ['서울특별시 성북구 장위동 월계로36길 27'],
#  ['서울특별시 성북구 정릉동 861-1'],
#  ['서울특별시 성북구 안암로 145'],
#  ['서울특별시 성북구 장위동 월계로36길 27'],
#  ['서울특별시 성북구 돈암동 동소문로34길 73'],
#  ['서울특별시 성북구 북악산로 844'],
#  ['서울특별시 강북구 미아동 숭인로7가길 37'],
#  ['서울특별시 성북구 회기로5길 100 ', '하월곡동'],
#  ['서울특별시 성북구 돈암동 동소문로34길 73'],
#  ['서울특별시 성북구 종암로25길 30 ', '종암동'],
#  ['서울특별시 강북구 도봉로 242'],
#  ['서울특별시 강북구 미아동 숭인로7가길 37'],
#  ['서울특별시 성북구 정릉동 솔샘로24길 15'],
#  ['서울특별시 강북구 오현로 156 ', '번동'],
#  ['서울특별시 강북구 도봉로 352'],
#  ['서울특별시 강북구 미아동 삼양로 256'],
#  ['서울특별시 성북구 돈암동 아리랑로 89'],
#  ['서울특별시 성북구 정릉동 북악산로 851'],
#  ['서울특별시 강북구 월계로21가길 41'],
#  ['서울특별시 성북구 하월곡동 종암로 167'],
#  ['서울특별시 성북구 장월로1길 28'],
#  ['서울특별시 성북구 동소문동7가 동소문로15길 99'],
#  ['서울특별시 성북구 보문로29다길 31 ', '삼선동2가'],
#  ['서울특별시 성북구 보문동4가 인촌로2길 37'],
#  ['서울특별시 성북구 삼선교로16길 35 ', '삼선동3가'],
#  ['서울특별시 성북구 회기로5길 100 ', '하월곡동'],
#  ['서울특별시 성북구 길음로 16'],
#  ['서울특별시 성북구 아리랑로5길 85'],
#  ['서울특별시 성북구 돈암동 아리랑로 89'],
#  ['서울특별시 강북구 월계로 173 ', '번동'],
#  ['서울특별시 성북구 동소문로 315 ', '길음동'],
#  ['서울특별시 강북구 삼각산로 85 ', '수유동'],
#  ['서울특별시 중구 퇴계로 140'],
#  ['서울특별시 중구 퇴계로 140']]

# %%
chargingDF['주소'].str.contains('[(]')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 638697    False
# 638698    False
# 638699    False
# 638700    False
# 638701    False
# Name: 주소, Length: 638702, dtype: object

# %%
chargingDF_2[chargingDF['주소'].str.contains('(')]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 chargingDF_2[chargingDF['주소'].str.contains('(')]
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py:1214, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1089 @forbid_nonstring_types(["bytes"])
#    1090 def contains(self, pat, case=True, flags=0, na=None, regex=True):
#    1091     r"""
#    1092     Test if pattern or regex is contained within a string of a Series or Index.
#    1093
#    (...)
#    1212     dtype: bool
#    1213     """
# -> 1214     if regex and re.compile(pat).groups:
#    1215         warnings.warn(
#    1216             "This pattern is interpreted as a regular expression, and has "
#    1217             "match groups. To actually get the groups, use str.extract.",
#    1218             UserWarning,
#    1219             stacklevel=find_stack_level(),
#    1220         )
#    1222     result = self._data.array._str_contains(pat, case, flags, na, regex)
#
# File ~\anaconda3\lib\re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File ~\anaconda3\lib\re.py:304, in _compile(pattern, flags)
#     302 if not sre_compile.isstring(pattern):
#     303     raise TypeError("first argument must be string or compiled pattern")
# --> 304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#     306     if len(_cache) >= _MAXCACHE:
#     307         # Drop the oldest item
#
# File ~\anaconda3\lib\sre_compile.py:764, in compile(p, flags)
#     762 if isstring(p):
#     763     pattern = p
# --> 764     p = sre_parse.parse(p, flags)
#     765 else:
#     766     pattern = None
#
# File ~\anaconda3\lib\sre_parse.py:950, in parse(str, flags, state)
#     947 state.str = str
#     949 try:
# --> 950     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     951 except Verbose:
#     952     # the VERBOSE flag was switched on inside the pattern.  to be
#     953     # on the safe side, we'll parse the whole thing again...
#     954     state = State()
#
# File ~\anaconda3\lib\sre_parse.py:443, in _parse_sub(source, state, verbose, nested)
#     441 start = source.tell()
#     442 while True:
# --> 443     itemsappend(_parse(source, state, verbose, nested + 1,
#     444                        not nested and not items))
#     445     if not sourcematch("|"):
#     446         break
#
# File ~\anaconda3\lib\sre_parse.py:838, in _parse(source, state, verbose, nested, first)
#     836 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     837 if not source.match(")"):
# --> 838     raise source.error("missing ), unterminated subpattern",
#     839                        source.tell() - start)
#     840 if group is not None:
#     841     state.closegroup(group, p)
#
# error: missing ), unterminated subpattern at position 0

# %%
hjDF['month'] = train.date_time.dt.month                    # 월(숫자)
hjDF['day'] = train.date_time.dt.day                        # 일(숫자)
hjDF['hour'] = train.date_time.dt.hour                      # 시(숫자)
hjDF['weekday'] = train.date_time.dt.weekday                # 요일(숫자)
hjDF['dayofyear'] = train.date_time.dt.dayofyear            # 연 기준 몇일째(숫자)
